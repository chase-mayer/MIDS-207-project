# %%
import pandas as pd
import numpy as np

# %%
df_weather = pd.read_csv('../data/interim/calfire_weather.csv')

# %%
df_weather[['incident_id','incident_dateonly_created','incident_longitude','incident_latitude']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3509 entries, 0 to 3508
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   incident_id                3509 non-null   object
#  1   incident_dateonly_created  3509 non-null   object
#  2   incident_longitude         3509 non-null   float64
#  3   incident_latitude          3509 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 109.8+ KB

# %%
# list(df_weather.columns)

# %%
df = df_weather[['incident_id','incident_dateonly_created','incident_longitude','incident_latitude']].copy()

# %%
df.rename(columns={'incident_id':'fire_incident_id','incident_dateonly_created':'fire_incident_date_created'},inplace=True)

# %%
df.to_csv('fire_details.csv')
