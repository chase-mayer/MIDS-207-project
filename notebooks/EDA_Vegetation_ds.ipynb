# %%
import pandas as pd
import numpy as np
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# CAL FIRE dataset
calfire_df = pd.read_csv("mapdataall.csv")

# Vegetation dataset
veg_df = pd.read_csv("FMR_202606100304.csv")

# %%
print("Cal fire")
print(calfire_df.head())
# Out:
# Cal fire
#    incident_name incident_is_final incident_date_last_update  \
# 0    Bridge Fire                 Y      2018-01-09T13:46:00Z
# 1      Pala Fire                 Y      2020-09-16T14:07:35Z
# 2     River Fire                 Y      2022-10-24T11:39:23Z
# 3  Fawnskin Fire                 Y      2013-04-22T09:00:00Z
# 4      Gold Fire                 Y      2013-05-01T07:00:00Z
#
#   incident_date_created          incident_administrative_unit  \
# 0  2017-10-31T11:22:00Z       Shasta-Trinity National Forest
# 1  2009-05-24T14:56:00Z               CAL FIRE San Diego Unit
# 2  2013-02-24T08:16:00Z          CAL FIRE San Bernardino Unit
# 3  2013-04-20T17:30:00Z        San Bernardino National Forest
# 4  2013-04-30T12:59:00Z  CAL FIRE Madera-Mariposa-Merced Unit
#
#    incident_administrative_unit_url incident_county  \
# 0                               NaN          Shasta
# 1                               NaN       San Diego
# 2                               NaN            Inyo
# 3                               NaN  San Bernardino
# 4                               NaN          Madera
#
#                                    incident_location  incident_acres_burned  \
# 0  I-5 and Turntable Bay, 7 miles NE of Shasta Lake                    37.0
# 1        Hwy 76 and Pala Temecula, northwest of Pala                  122.0
# 2  south of Narrow Gauge Rd & north of Hwy 136, e...                  407.0
# 3  west of Delamar Mountain, north of the communi...                   30.0
# 4  Between Road 210 and Road 200 near Fine Gold C...                  274.0
#
#    incident_containment  ... incident_latitude incident_type  \
# 0                 100.0  ...         40.774000           NaN
# 1                 100.0  ...          1.000000      Wildfire
# 2                 100.0  ...         36.602575           NaN
# 3                 100.0  ...         34.288877           NaN
# 4                 100.0  ...         37.116295           NaN
#
#                             incident_id  \
# 0  2ca11d45-8139-4c16-8af0-880d99b21e82
# 1  8f61f461-552d-4538-b186-35ab030da416
# 2  094719ba-a47b-4abb-9ec5-a506b2b9fd23
# 3  58f89ff8-bd3e-4355-b1c0-8fa05c747d3f
# 4  357ffc13-bef9-48eb-810f-c5de851972eb
#
#                                         incident_url  \
# 0  https://www.fire.ca.gov/incidents/2017/10/31/b...
# 1  https://www.fire.ca.gov/incidents/2009/5/24/pa...
# 2  https://www.fire.ca.gov/incidents/2013/2/24/ri...
# 3  https://www.fire.ca.gov/incidents/2013/4/20/fa...
# 4  https://www.fire.ca.gov/incidents/2013/4/30/go...
#
#   incident_date_extinguished incident_dateonly_extinguished  \
# 0       2018-01-09T13:46:00Z                     2018-01-09
# 1       2009-05-25T00:00:00Z                     2009-05-25
# 2       2013-02-28T20:00:00Z                     2013-02-28
# 3       2013-04-22T09:00:00Z                     2013-04-22
# 4       2013-05-01T07:00:00Z                     2013-05-01
#
#   incident_dateonly_created is_active calfire_incident notification_desired
# 0                2017-10-31         N            False                False
# 1                2009-05-24         N             True                False
# 2                2013-02-24         N             True                False
# 3                2013-04-20         N            False                False
# 4                2013-04-30         N             True                False
#
# [5 rows x 23 columns]

# %%
print("Vegetation")
print(veg_df.head())

print("\nCal fire shape")
print(calfire_df.shape)

print("\nVege shape")
print(veg_df.shape)

print("\nCalfire columns")
print(calfire_df.columns)

print("\nVege columns")
print(veg_df.columns)
# Out:
# Vegetation
#    STID        DATE FUEL_TYPE FUEL_VARIATION  PERCENT           NAME  GACC  \
# 0     2  2014-06-03      Duff            NaN      7.0  12 Rd @ 54 Rd  NOCC
# 1     2  2014-07-15      Duff            NaN     12.0  12 Rd @ 54 Rd  NOCC
# 2     2  2014-08-27      Duff            NaN     16.0  12 Rd @ 54 Rd  NOCC
# 3     2  2015-06-04      Duff            NaN    144.0  12 Rd @ 54 Rd  NOCC
# 4     2  2015-06-30      Duff            NaN     12.0  12 Rd @ 54 Rd  NOCC
#
#       GROUP        LAT         LON     ELE
# 0  Tahoe NF  39.570556 -120.492778  7600.0
# 1  Tahoe NF  39.570556 -120.492778  7600.0
# 2  Tahoe NF  39.570556 -120.492778  7600.0
# 3  Tahoe NF  39.570556 -120.492778  7600.0
# 4  Tahoe NF  39.570556 -120.492778  7600.0
#
# Cal fire shape
# (3509, 23)
#
# Vege shape
# (48944, 11)
#
# Calfire columns
# Index(['incident_name', 'incident_is_final', 'incident_date_last_update',
#        'incident_date_created', 'incident_administrative_unit',
#        'incident_administrative_unit_url', 'incident_county',
#        'incident_location', 'incident_acres_burned', 'incident_containment',
#        'incident_control', 'incident_cooperating_agencies',
#        'incident_longitude', 'incident_latitude', 'incident_type',
#        'incident_id', 'incident_url', 'incident_date_extinguished',
#        'incident_dateonly_extinguished', 'incident_dateonly_created',
#        'is_active', 'calfire_incident', 'notification_desired'],
#       dtype='str')
#
# Vege columns
# Index(['STID', 'DATE', 'FUEL_TYPE', 'FUEL_VARIATION', 'PERCENT', 'NAME',
#        'GACC', 'GROUP', 'LAT', 'LON', 'ELE'],
#       dtype='str')

# %%
calfire_df["fire_date"] = (
    pd.to_datetime(
        calfire_df["incident_date_created"],
        errors="coerce",
        utc=True
    )
    .dt.tz_localize(None)
    .dt.normalize()
)

veg_df["veg_date"] = (
    pd.to_datetime(
        veg_df["DATE"],
        errors="coerce"
    )
    .dt.normalize()
)

calfire_df = calfire_df.rename(columns={
    "incident_latitude": "fire_LAT",
    "incident_longitude": "fire_LON"
})

veg_df = veg_df.rename(columns={
    "LAT": "veg_LAT",
    "LON": "veg_LON"
})

calfire_clean = calfire_df.dropna(
    subset=["fire_LAT", "fire_LON", "fire_date"]
).copy()

veg_clean = veg_df.dropna(
    subset=["veg_LAT", "veg_LON", "veg_date"]
).copy()


calfire_clean["fire_LAT"] = pd.to_numeric(calfire_clean["fire_LAT"], errors="coerce")
calfire_clean["fire_LON"] = pd.to_numeric(calfire_clean["fire_LON"], errors="coerce")

veg_clean["veg_LAT"] = pd.to_numeric(veg_clean["veg_LAT"], errors="coerce")
veg_clean["veg_LON"] = pd.to_numeric(veg_clean["veg_LON"], errors="coerce")

calfire_clean = calfire_clean.dropna(subset=["fire_LAT", "fire_LON"])
veg_clean = veg_clean.dropna(subset=["veg_LAT", "veg_LON"])

calfire_clean = calfire_clean.reset_index(drop=True)
calfire_clean["fire_id"] = calfire_clean.index

# %%
print("Original calfire_df:", len(calfire_df))
print("After first dropna:", len(calfire_clean))
print("Rows removed:", len(calfire_df) - len(calfire_clean))
# Out:
# Original calfire_df: 3509
# After first dropna: 3509
# Rows removed: 0

# %%
# Earliest vegetation date
min_veg_date = veg_df["veg_date"].min()
print("Earliest vegetation date:", min_veg_date)

# How many fires occurred before vegetation data begins?
fires_before_veg = (calfire_df["fire_date"] < min_veg_date).sum()

print("Fire rows before vegetation data starts:", fires_before_veg)
print("Total fire rows:", len(calfire_df))
print("Percent:", fires_before_veg / len(calfire_df) * 100)
# Out:
# Earliest vegetation date: 2013-01-02 00:00:00
# Fire rows before vegetation data starts: 3
# Total fire rows: 3509
# Percent: 0.08549444286121402

# %%
# Geographical location can hardly be mapped to the exact, therefore I tried finding the nearest data point to map.

veg_locations = (
    veg_clean[["veg_LAT", "veg_LON"]]
    .drop_duplicates()
    .reset_index(drop=True)
)

tree = cKDTree(veg_locations[["veg_LAT", "veg_LON"]].values)

fire_coords = calfire_clean[["fire_LAT", "fire_LON"]].values

distances, indices = tree.query(fire_coords, k=1)

matched_locations = veg_locations.iloc[indices].reset_index(drop=True)

calfire_clean["matched_veg_LAT"] = matched_locations["veg_LAT"]
calfire_clean["matched_veg_LON"] = matched_locations["veg_LON"]
calfire_clean["location_distance_degrees"] = distances


merged = calfire_clean.merge(
    veg_clean,
    left_on=["matched_veg_LAT", "matched_veg_LON"],
    right_on=["veg_LAT", "veg_LON"],
    how="left"
)

merged = merged[merged["veg_date"] <= merged["fire_date"]].copy()
merged["date_gap_days"] = (
    merged["fire_date"] - merged["veg_date"]
).dt.days

result = (
    merged
    .sort_values(["fire_id", "date_gap_days"])
    .groupby("fire_id")
    .head(1)
    .reset_index(drop=True)
)

# %%
merged0 = calfire_clean.merge(
    veg_clean,
    left_on=["matched_veg_LAT", "matched_veg_LON"],
    right_on=["veg_LAT", "veg_LON"],
    how="left"
)

print("calfire_clean rows:", len(calfire_clean))
print("after merge rows:", len(merged0))
print("unique fires after merge:", merged0["fire_id"].nunique())

merged1 = merged0[merged0["veg_date"] <= merged0["fire_date"]].copy()

print("after date filter rows:", len(merged1))
print("unique fires after date filter:", merged1["fire_id"].nunique())
print("lost fires:", calfire_clean["fire_id"].nunique() - merged1["fire_id"].nunique())
# Out:
# calfire_clean rows: 3509
# after merge rows: 535158
# unique fires after merge: 3509
# after date filter rows: 331277
# unique fires after date filter: 2655
# lost fires: 854

# %%
result[[
    "incident_name",
    "fire_date",
    "fire_LAT",
    "fire_LON",
    "matched_veg_LAT",
    "matched_veg_LON",
    "veg_date",
    "date_gap_days",
    "FUEL_TYPE",
    "PERCENT",
    "GROUP"
]].head()
# Out:
#      incident_name  fire_date   fire_LAT    fire_LON  matched_veg_LAT  \
# 0      Bridge Fire 2017-10-31  40.774000 -122.309000        40.870833
# 1        Lake Fire 2013-05-17  34.491490 -118.610044        34.510000
# 2     Shelton Fire 2013-05-30  38.049930 -120.903250        38.114722
# 3      Border Fire 2013-05-22  32.564465 -116.900368        32.666389
# 4  San Felipe Fire 2013-05-23  33.121110 -116.525790        33.197500
#
#    matched_veg_LON   veg_date  date_gap_days  FUEL_TYPE  PERCENT  \
# 0      -122.389722 2017-10-18             13  Manzanita     73.0
# 1      -118.594500 2013-05-17              0    Chamise     61.0
# 2      -120.790000 2013-05-23              7    Chamise     82.0
# 3      -116.700000 2013-05-20              2    Chamise     88.0
# 4      -116.598056 2013-05-23              0    Chamise     90.0
#
#                               GROUP
# 0                 Shasta-Trinity NF
# 1                         LA County
# 2  CAL FIRE Toulumne-Calaveras Unit
# 3                             SDG&E
# 4                             SDG&E

# %%
result.to_csv("calfire_vegetation.csv", index=False)

# %%
result.head()
# Out:
#      incident_name incident_is_final incident_date_last_update  \
# 0      Bridge Fire                 Y      2018-01-09T13:46:00Z
# 1        Lake Fire                 Y      2013-05-18T19:00:00Z
# 2     Shelton Fire                 Y      2013-05-30T13:25:00Z
# 3      Border Fire                 Y      2013-05-23T08:30:00Z
# 4  San Felipe Fire                 Y      2022-10-24T11:41:15Z
#
#   incident_date_created       incident_administrative_unit  \
# 0  2017-10-31T11:22:00Z    Shasta-Trinity National Forest
# 1  2013-05-17T13:23:00Z       CAL FIRE/Los Angeles County
# 2  2013-05-30T11:20:00Z  CAL FIRE Tuolumne-Calaveras Unit
# 3  2013-05-22T16:14:00Z            CAL FIRE San Diego Unit
# 4  2013-05-23T12:20:00Z            CAL FIRE San Diego Unit
#
#    incident_administrative_unit_url incident_county  \
# 0                               NaN          Shasta
# 1                               NaN     Los Angeles
# 2                               NaN     San Joaquin
# 3                               NaN       San Diego
# 4                               NaN       San Diego
#
#                                    incident_location  incident_acres_burned  \
# 0  I-5 and Turntable Bay, 7 miles NE of Shasta Lake                    37.0
# 1                 I-5 Southbound at Lake Hughes Road                  712.0
# 2     off North Shelton Rd in the Linden Peters area                  303.0
# 3                  Off Alta Rd in the Otay Mesa area                  100.0
# 4  San Felipe Road, north of Highway 78, East of ...                 2650.0
#
#    incident_containment  ... FUEL_VARIATION PERCENT                    NAME  \
# 0                 100.0  ...      Whiteleaf    73.0               Lakeshore
# 1                 100.0  ...            NaN    61.0  Bitter Canyon, Castaic
# 2                 100.0  ...     New Growth    82.0          Valley Springs
# 3                 100.0  ...     New Growth    88.0                 Barrett
# 4                 100.0  ...     New Growth    90.0              San Felipe
#
#    GACC                             GROUP    veg_LAT     veg_LON     ELE  \
# 0  NOCC                 Shasta-Trinity NF  40.870833 -122.389722  1085.0
# 1  SOCC                         LA County  34.510000 -118.594500  1745.0
# 2  SOCC  CAL FIRE Toulumne-Calaveras Unit  38.114722 -120.790000   908.0
# 3  SOCC                             SDG&E  32.666389 -116.700000  2500.0
# 4  SOCC                             SDG&E  33.197500 -116.598056  3452.0
#
#     veg_date date_gap_days
# 0 2017-10-18            13
# 1 2013-05-17             0
# 2 2013-05-23             7
# 3 2013-05-20             2
# 4 2013-05-23             0
#
# [5 rows x 41 columns]

# %% [markdown]
# EDA!

# %%
result["log_acres_burned"] = np.log1p(
    result["incident_acres_burned"]
)


fuel_summary = (
    result.groupby("FUEL_TYPE")
    .agg(
        fire_count=("incident_name", "count"),
        mean_acres=("incident_acres_burned", "mean"),
        median_acres=("incident_acres_burned", "median"),
        mean_log_acres=("log_acres_burned", "mean")
    )
    .sort_values("mean_log_acres", ascending=False)
)

fuel_summary.head(20)

top_fuels = fuel_summary.head(10)

plt.figure(figsize=(10,6))

plt.bar(
    top_fuels.index,
    top_fuels["mean_log_acres"]
)

plt.xticks(rotation=45)
plt.ylabel("Mean Log Acres Burned")
plt.title("Top Fuel Types by Fire Size")

plt.show()

# %%
group_summary = (
    result.groupby("GROUP")
    .agg(
        fire_count=("incident_name", "count"),
        mean_log_acres=("log_acres_burned", "mean")
    )
    .sort_values("mean_log_acres", ascending=False)
)

group_summary.head(20)
# Out:
#                               fire_count  mean_log_acres
# GROUP
# Inyo NF                                7        6.793628
# Shasta-Trinity NF                     21        6.738445
# Lake Tahoe Basin M.U.                  7        6.226450
# Plumas NF                             11        5.980780
# Orange County Fire                    22        5.813686
# Angeles NF                            33        5.695030
# Klamath NF                            65        5.683024
# Los Padres NF                         69        5.556799
# Kern County FD                        44        5.523671
# Tahoe NF                              33        5.520673
# Sequoia-Kings NP                      26        5.493886
# LA County                             60        5.358703
# CalFire Mendocino Unit                13        5.324016
# Ventura County FD                     28        5.293513
# Modoc NF                              47        5.187610
# Six Rivers NF                         40        5.186958
# CAL FIRE Lassen-Modoc Unit            35        5.127222
# Santa Barbara County FD               34        5.113680
# CAL FIRE San Bernardino Unit           8        5.031007
# BLM -Northern CA District             39        5.022596

# %%
result["PERCENT"] = pd.to_numeric(
    result["PERCENT"],
    errors="coerce"
)

result[["PERCENT", "log_acres_burned"]].corr()

plt.figure(figsize=(6,4))

plt.scatter(
    result["PERCENT"],
    result["log_acres_burned"],
    alpha=0.4
)

plt.xlabel("Fuel Moisture Percent")
plt.ylabel("Log Acres Burned")
plt.title("Fuel Moisture vs Fire Size")

plt.show()

# %%
top_fuel_names = (
    result["FUEL_TYPE"]
    .value_counts()
    .head(10)
    .index
)

plot_df = result[
    result["FUEL_TYPE"].isin(top_fuel_names)
]

plt.figure(figsize=(12,6))

sns.boxplot(
    data=plot_df,
    x="FUEL_TYPE",
    y="log_acres_burned"
)

plt.xticks(rotation=45)
plt.title("Fire Size Distribution by Fuel Type")

plt.show()
