# %%
# Author: Sreeram Chennakrishnan
# Email: sreeram.c@berkeley.edu
# Project: W207 - Fire & Drought data analysis

# %%
# Import libraries
import numpy as np
import pandas as pd

# %%
# Import the firedataset
ds_calfire = pd.read_csv("../data/raw/mapdataall.csv")

# %%
ds_calfire.shape
# Out:
# (3509, 23)

# %%
ds_calfire.head(2)
# Out:
#   incident_name incident_is_final incident_date_last_update  \
# 0   Bridge Fire                 Y      2018-01-09T13:46:00Z
# 1     Pala Fire                 Y      2020-09-16T14:07:35Z
#
#   incident_date_created      incident_administrative_unit  \
# 0  2017-10-31T11:22:00Z   Shasta-Trinity National Forest
# 1  2009-05-24T14:56:00Z           CAL FIRE San Diego Unit
#
#    incident_administrative_unit_url incident_county  \
# 0                               NaN          Shasta
# 1                               NaN       San Diego
#
#                                    incident_location  incident_acres_burned  \
# 0  I-5 and Turntable Bay, 7 miles NE of Shasta Lake                    37.0
# 1        Hwy 76 and Pala Temecula, northwest of Pala                  122.0
#
#    incident_containment  ... incident_latitude incident_type  \
# 0                 100.0  ...            40.774           NaN
# 1                 100.0  ...             1.000      Wildfire
#
# ...

# %%
ds_calfire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3509 entries, 0 to 3508
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   incident_name                     3509 non-null   object
#  1   incident_is_final                 3509 non-null   object
#  2   incident_date_last_update         3509 non-null   object
#  3   incident_date_created             3509 non-null   object
#  4   incident_administrative_unit      3443 non-null   object
#  5   incident_administrative_unit_url  0 non-null      float64
#  6   incident_county                   3499 non-null   object
#  7   incident_location                 3509 non-null   object
#  8   incident_acres_burned             3455 non-null   float64
#  9   incident_containment              3456 non-null   float64
#  10  incident_control                  119 non-null    object
# ...

# %%
ds_calfire.groupby('incident_is_final')['incident_name'].count()
# Out:
# incident_is_final
# N      34
# Y    3475
# Name: incident_name, dtype: int64
